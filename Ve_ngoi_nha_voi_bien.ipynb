# %%
import turtle as t
pen=t.Turtle()
t.bgcolor("cyan")
pen.speed(200)
pen.fillcolor ("blue")
a=150
b=125
c=90
d=100
e=50
f=120
g=30
h=60
j=45
k=55
l=25
x=85
pen.penup()
pen.goto(-300,-200)
pen.pendown()
pen.begin_fill()
pen.forward(b)
pen.left(c)
pen.forward(a)
pen.left(c)
pen.forward(b)
pen.left(c)
pen.forward(a)
pen.left(c)
pen.forward(b)
pen.left(g)
pen.end_fill()

pen.fillcolor ("yellow")
pen.begin_fill()
pen.forward(d)
pen.left(h)
pen.forward(a)
pen.left(f)
pen.forward(d)
pen.end_fill()
pen.right(g)
pen.right(h)

pen.fillcolor ("red")
pen.begin_fill()
pen.forward(b)
pen.left(f)
pen.forward(b)
pen.left(f)
pen.forward(b)
pen.left(g)
pen.end_fill()

pen.fillcolor ("orange")
pen.begin_fill()
pen.forward(d)
pen.left(c)
pen.forward(b)
pen.left(c)
pen.forward(d)
pen.left(a)
pen.end_fill()

pen.fillcolor ("green")
pen.begin_fill()
pen.penup()
pen.goto(-260,-200)
pen.pendown()
pen.forward(e)
pen.left(c)
pen.forward(e)
pen.left(c)
pen.forward(e)
pen.left(c)
pen.forward(e)
pen.left(c)
pen.end_fill()

pen.fillcolor ("brown")
pen.begin_fill()
pen.penup()
pen.goto(-150,-125)
pen.pendown()
pen.left(g)
pen.forward(j)
pen.left(h)
pen.forward(k)
pen.left(f)
pen.forward(j)
pen.left(h)
pen.forward(k)
pen.end_fill()

pen.fillcolor ("yellow")
pen.penup()
pen.goto(100,a)
pen.pendown()
pen.begin_fill()
pen.circle(e)
pen.end_fill()

pen.right(c)
pen.forward(e)
pen.penup()
pen.goto(200,a)
pen.pendown()
pen.backward(e)
pen.penup()
pen.goto(a,100)
pen.pendown()
pen.right(c)
pen.backward(e)
pen.penup()
pen.goto(a,200)
pen.pendown()
pen.forward(e)
pen.penup()
pen.goto(115,185)
pen.pendown()
pen.left(j)
pen.forward(l)
pen.penup()
pen.backward(b)
pen.pendown()
pen.backward(l)
pen.penup()
pen.goto(115,115)
pen.pendown()
pen.right(c)
pen.backward(l)
pen.penup()
pen.forward(b)
pen.pendown()
pen.forward(l)
pen.right(j)

pen.fillcolor ("brown")
pen.begin_fill()
pen.penup()
pen.goto(100,-250)
pen.pendown()
pen.forward(l)
pen.left(c)
pen.forward(e)
pen.left(c)
pen.forward(l)
pen.left(c)
pen.forward(e)
pen.end_fill()

pen.fillcolor ("green")
pen.begin_fill()
pen.penup()
pen.goto(70,-200)
pen.left(c)
pen.pendown()
pen.forward(x)
pen.left(f)
pen.forward(x)
pen.left(f)
pen.forward(x)
pen.left(f)
pen.end_fill()

pen.fillcolor ("green")
pen.begin_fill()
pen.penup()
pen.goto(70,-125)
pen.pendown()
pen.forward(x)
pen.left(f)
pen.forward(x)
pen.left(f)
pen.forward(x)
pen.left(f)
pen.end_fill()

pen.fillcolor ("green")
pen.begin_fill()
pen.penup()
pen.goto(70,-50)
pen.pendown()
pen.forward(x)
pen.left(f)
pen.forward(x)
pen.left(f)
pen.forward(x)
pen.left(f)
pen.end_fill()

pen.penup()
pen.goto(-200,-250)
pen.pendown()
t.done()
